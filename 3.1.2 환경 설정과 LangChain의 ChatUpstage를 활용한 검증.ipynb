# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: c:\Users\koko5\.pyenv\pyenv-win\versions\3.10.11\python.exe -m pip install --upgrade pip

# %% [markdown]
# # 2. 환경변수 불러오기
#
# - `.env` 파일에 `OPENAI_API_KEY` 등록

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 3. LLM 답변 생성
#
# - Upstage Console에서 발급받은 API Key를 `UPSTAGE_API_KEY`라고 저장하면 별도의 설정 없이 `ChatUpstage`를 사용할 수 있음

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 온라인 강의가 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: Python, Java, JavaScript, Kotlin, Swift 등 다양한 프로그래밍 언어 강의를 제공합니다. 웹 개발, 모바일 개발, 게임 개발, 데이터 과학, 머신러닝 등 다양한 주제가 포함됩니다.\n\n2. **디자인**: UI/UX 디자인, 그래픽 디자인, 웹 디자인, 비디오 편집, 3D 모델링 등 디자인 관련 강의를 제공합니다.\n\n3. **비즈니스**: 마케팅, 경영, 재무, 회계, 인사 등 비즈니스 관련 강의를 제공합니다.\n\n4. **인문학**: 심리학, 철학, 역사, 사회학 등 인문학 관련 강의를 제공합니다.\n\n5. **자기계발**: 생산성 향상, 시간 관리, 리더십, 커뮤니케이션 등 자기계발 관련 강의를 제공합니다.\n\n6. **기타**: 사진 촬영, 음악 제작, 요리, 건강 등 다양한 주제의 강의가 있습니다.\n\n각 강의는 전문가가 직접 제작하고, 실습 중심 또는 이론 중심으로 구성되어 있어 학습자의 필요에 맞는 강의를 선택할 수 있습니다. 인프런 웹사이트나 앱을 통해 더 자세한 내용을 확인할 수 있습니다.'
